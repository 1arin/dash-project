# %%
import pandas as pd

# %%
data = pd.read_csv('clean_data2.csv')
data
# Out:
#       Unnamed: 0         DATETIMEDATA  PM25  PM10   O3    CO    NO2   SO2  \
# 0              0  2024-01-01 00:00:00  30.3  47.0  6.0  0.50   9.00  0.34
# 1              1  2024-01-01 01:00:00  37.7  65.0  5.0  0.41   5.00  0.34
# 2              2  2024-01-01 02:00:00  50.9  78.0  9.0  0.29   2.00  0.34
# 3              3  2024-01-01 03:00:00  45.1  66.0  9.0  0.38   2.00  0.34
# 4              4  2024-01-01 04:00:00  38.1  59.0  6.0  0.31   7.11  0.34
# ...          ...                  ...   ...   ...  ...   ...    ...   ...
# 1625        1627  2024-03-08 19:00:00   7.1  27.0  5.0  0.31  10.00  0.34
# 1626        1628  2024-03-08 20:00:00   7.3  27.0  6.0  0.31   9.00  0.34
# 1627        1629  2024-03-08 21:00:00   9.3  32.0  3.0  0.48  12.00  0.34
# 1628        1630  2024-03-08 22:00:00  11.3  32.0  2.0  0.73  11.00  0.34
# 1629        1631  2024-03-08 23:00:00  16.5  31.0  2.0  0.54   8.00  0.34
#
#        WS  TEMP  RH     WD
# 0     0.6    25  92  232.0
# ...

# %%
from pycaret.regression import *
setup101 = setup(data, target='PM25', session_id = 123)
best_model = compare_models()
tuned = tune_model(best_model)
bagged = ensemble_model(tuned , n_estimators=50)
# Out:
# <style type="text/css">
# #T_93537_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_93537">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93537_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_93537_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93537_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93537_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_93537_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_93537_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93537_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_93537_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_93537_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
model_en = create_model('en')
save_model(model_en, 'model_en_pipeline')
load_model('model_en_pipeline')
predict_model(model_en)
# Out:
# <style type="text/css">
# #T_aabfd_row10_col0, #T_aabfd_row10_col1, #T_aabfd_row10_col2, #T_aabfd_row10_col3, #T_aabfd_row10_col4, #T_aabfd_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_aabfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aabfd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_aabfd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_aabfd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_aabfd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_aabfd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_aabfd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
